# %%
from data_stored import get_stored_data
from index_map import indexes
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
(ref, trans, obj, imgNames, source) = get_stored_data(full=True)
ix = indexes()

# %%
wantedKey = []
for key in ix:
    if 'zoo' in key:
        wantedKey.append(key)

wantedInds = []
for i, name in enumerate(imgNames):
    if name in wantedKey:
        wantedInds.append(i)

# %%
for i, o in enumerate(source):
    if 'vagabundo' in o:
        print(i)
# Out:
# 10123
# 24497
# 25569

# %%
imgIndex = 10123

# print(obj[imgIndex])
print("English: " + ref[imgIndex][:-1])
print("Spanish: " + source[imgIndex][:-1])

img = mpimg.imread("images-en-es/files/" + ix[imgNames[imgIndex]])
imgplot = plt.imshow(img)
plt.axis('off')
plt.show()

# print("Translations: " + str(trans[imgIndex]))
# Out:
# English: Feral dog in Pompeii
# Spanish: perro vagabundo en Pompeya
